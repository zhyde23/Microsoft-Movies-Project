# %%
import pandas as pd
import os
from glob import glob

# %%
# glob finds all the files in a specified directory that match the condition
# we do this so we can open multiple files at once
csv_files = glob("./zippedData/*.csv.gz")
csv_files
# Out:
# ['./zippedData/imdb.title.crew.csv.gz',
#  './zippedData/tmdb.movies.csv.gz',
#  './zippedData/imdb.title.akas.csv.gz',
#  './zippedData/imdb.title.ratings.csv.gz',
#  './zippedData/imdb.name.basics.csv.gz',
#  './zippedData/imdb.title.basics.csv.gz',
#  './zippedData/tn.movie_budgets.csv.gz',
#  './zippedData/bom.movie_gross.csv.gz',
#  './zippedData/imdb.title.principals.csv.gz']

# %%
# tsv files, because later tsv files need to be opened with sep='\t'
tsv_files = glob("./Unused Data/*.tsv.gz")
tsv_files
# Out:
# ['./Unused Data/rt.reviews.tsv.gz', './Unused Data/rt.movie_info.tsv.gz']

# %%
data_dict = {}

for file in csv_files:
    data_dict[file] = pd.read_csv(file)
    
for file in tsv_files:
    data_dict[file] = pd.read_csv(file, sep='\t', encoding= 'unicode_escape')

# %%
df2 = data_dict['./zippedData/bom.movie_gross.csv.gz']
df2.head()
# Out:
#                                          title studio  domestic_gross  \
# 0                                  Toy Story 3     BV     415000000.0
# 1                   Alice in Wonderland (2010)     BV     334200000.0
# 2  Harry Potter and the Deathly Hallows Part 1     WB     296000000.0
# 3                                    Inception     WB     292600000.0
# 4                          Shrek Forever After   P/DW     238700000.0
#
#   foreign_gross  year
# 0     652000000  2010
# 1     691300000  2010
# 2     664300000  2010
# 3     535700000  2010
# 4     513900000  2010

# %%
# To join these two dataframes, I'm thinking that we can do it by joining the domestic/foreign gross.
# The only thing is, in bon.movie_gross has the numbers rounded to the nearest 100k's whereas the 
# tn.movie_budgets is specific to the last dollar. I would have to convert the tn.movie_budgets columns
# to rounded numbers to then join the two dataframes.

# %%
df = data_dict['./zippedData/tmdb.movies.csv.gz']
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26517 entries, 0 to 26516
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Unnamed: 0         26517 non-null  int64
#  1   genre_ids          26517 non-null  object
#  2   id                 26517 non-null  int64
#  3   original_language  26517 non-null  object
#  4   original_title     26517 non-null  object
#  5   popularity         26517 non-null  float64
#  6   release_date       26517 non-null  object
#  7   title              26517 non-null  object
#  8   vote_average       26517 non-null  float64
#  9   vote_count         26517 non-null  int64
# dtypes: float64(2), int64(3), object(5)
# memory usage: 2.0+ MB

# %%
df.keys()
# Out:
# Index(['Unnamed: 0', 'genre_ids', 'id', 'original_language', 'original_title',
#        'popularity', 'release_date', 'title', 'vote_average', 'vote_count'],
#       dtype='object')

# %%
type('genre_ids')
# Out:
# str

# %%
df.head()
# Out:
#    Unnamed: 0            genre_ids     id original_language  \
# 0           0      [12, 14, 10751]  12444                en
# 1           1  [14, 12, 16, 10751]  10191                en
# 2           2        [12, 28, 878]  10138                en
# 3           3      [16, 35, 10751]    862                en
# 4           4        [28, 878, 12]  27205                en
#
#                                  original_title  popularity release_date  \
# 0  Harry Potter and the Deathly Hallows: Part 1      33.533   2010-11-19
# 1                      How to Train Your Dragon      28.734   2010-03-26
# 2                                    Iron Man 2      28.515   2010-05-07
# 3                                     Toy Story      28.005   1995-11-22
# 4                                     Inception      27.920   2010-07-16
#
#                                           title  vote_average  vote_count
# 0  Harry Potter and the Deathly Hallows: Part 1           7.7       10788
# 1                      How to Train Your Dragon           7.7        7610
# 2                                    Iron Man 2           6.8       12368
# 3                                     Toy Story           7.9       10174
# 4                                     Inception           8.3       22186

# %%
di = {"genres":[{"id":28,"name":"Action"},{"id":12,"name":"Adventure"},{"id":16,"name":"Animation"},{"id":35,"name":"Comedy"},{"id":80,"name":"Crime"},{"id":99,"name":"Documentary"},{"id":18,"name":"Drama"},{"id":10751,"name":"Family"},{"id":14,"name":"Fantasy"},{"id":36,"name":"History"},{"id":27,"name":"Horror"},{"id":10402,"name":"Music"},{"id":9648,"name":"Mystery"},{"id":10749,"name":"Romance"},{"id":878,"name":"Science Fiction"},{"id":10770,"name":"TV Movie"},{"id":53,"name":"Thriller"},{"id":10752,"name":"War"},{"id":37,"name":"Western"}]}

# %%
print(di)
# Out:
# {'genres': [{'id': 28, 'name': 'Action'}, {'id': 12, 'name': 'Adventure'}, {'id': 16, 'name': 'Animation'}, {'id': 35, 'name': 'Comedy'}, {'id': 80, 'name': 'Crime'}, {'id': 99, 'name': 'Documentary'}, {'id': 18, 'name': 'Drama'}, {'id': 10751, 'name': 'Family'}, {'id': 14, 'name': 'Fantasy'}, {'id': 36, 'name': 'History'}, {'id': 27, 'name': 'Horror'}, {'id': 10402, 'name': 'Music'}, {'id': 9648, 'name': 'Mystery'}, {'id': 10749, 'name': 'Romance'}, {'id': 878, 'name': 'Science Fiction'}, {'id': 10770, 'name': 'TV Movie'}, {'id': 53, 'name': 'Thriller'}, {'id': 10752, 'name': 'War'}, {'id': 37, 'name': 'Western'}]}

# %%
df['genre_ids']
# Out:
# 0            [12, 14, 10751]
# 1        [14, 12, 16, 10751]
# 2              [12, 28, 878]
# 3            [16, 35, 10751]
# 4              [28, 878, 12]
#                 ...
# 26512               [27, 18]
# 26513               [18, 53]
# 26514           [14, 28, 12]
# 26515        [10751, 12, 28]
# 26516               [53, 27]
# Name: genre_ids, Length: 26517, dtype: object

# %%
new_dict = {}
for i in range(0, len(di['genres'])):
    new_id = str(di['genres'][i]['id'])
    new_dict[new_id] = di['genres'][i]['name']
new_dict
# Out:
# {'28': 'Action',
#  '12': 'Adventure',
#  '16': 'Animation',
#  '35': 'Comedy',
#  '80': 'Crime',
#  '99': 'Documentary',
#  '18': 'Drama',
#  '10751': 'Family',
#  '14': 'Fantasy',
#  '36': 'History',
#  '27': 'Horror',
#  '10402': 'Music',
#  '9648': 'Mystery',
#  '10749': 'Romance',
#  '878': 'Science Fiction',
#  '10770': 'TV Movie',
#  '53': 'Thriller',
#  '10752': 'War',
#  '37': 'Western'}

# %%
y = df[['Unnamed: 0', 'genre_ids']]
y['genre_ids'] = y['genre_ids'].str.strip('[]')
df2 = pd.DataFrame(y['genre_ids'].str.split(', ').values.tolist())
df2
# Out:
# /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#            0    1      2      3     4     5     6
# 0         12   14  10751   None  None  None  None
# 1         14   12     16  10751  None  None  None
# 2         12   28    878   None  None  None  None
# 3         16   35  10751   None  None  None  None
# 4         28  878     12   None  None  None  None
# ...      ...  ...    ...    ...   ...   ...   ...
# 26512     27   18   None   None  None  None  None
# 26513     18   53   None   None  None  None  None
# 26514     14   28     12   None  None  None  None
# 26515  10751   12     28   None  None  None  None
# 26516     53   27   None   None  None  None  None
#
# [26517 rows x 7 columns]

# %%
df2[0]=df2[0].map(new_dict)
df2
# Out:
#                0    1      2      3     4     5     6
# 0      Adventure   14  10751   None  None  None  None
# 1        Fantasy   12     16  10751  None  None  None
# 2      Adventure   28    878   None  None  None  None
# 3      Animation   35  10751   None  None  None  None
# 4         Action  878     12   None  None  None  None
# ...          ...  ...    ...    ...   ...   ...   ...
# 26512     Horror   18   None   None  None  None  None
# 26513      Drama   53   None   None  None  None  None
# 26514    Fantasy   28     12   None  None  None  None
# 26515     Family   12     28   None  None  None  None
# 26516   Thriller   27   None   None  None  None  None
#
# [26517 rows x 7 columns]

# %%
df2[1]=df2[1].map(new_dict)
df2
# Out:
#                0                1      2      3     4     5     6
# 0      Adventure          Fantasy  10751   None  None  None  None
# 1        Fantasy        Adventure     16  10751  None  None  None
# 2      Adventure           Action    878   None  None  None  None
# 3      Animation           Comedy  10751   None  None  None  None
# 4         Action  Science Fiction     12   None  None  None  None
# ...          ...              ...    ...    ...   ...   ...   ...
# 26512     Horror            Drama   None   None  None  None  None
# 26513      Drama         Thriller   None   None  None  None  None
# 26514    Fantasy           Action     12   None  None  None  None
# 26515     Family        Adventure     28   None  None  None  None
# 26516   Thriller           Horror   None   None  None  None  None
#
# [26517 rows x 7 columns]

# %%
df2[2]=df2[2].map(new_dict)
df2
# Out:
#                0                1                2      3     4     5     6
# 0      Adventure          Fantasy           Family   None  None  None  None
# 1        Fantasy        Adventure        Animation  10751  None  None  None
# 2      Adventure           Action  Science Fiction   None  None  None  None
# 3      Animation           Comedy           Family   None  None  None  None
# 4         Action  Science Fiction        Adventure   None  None  None  None
# ...          ...              ...              ...    ...   ...   ...   ...
# 26512     Horror            Drama              NaN   None  None  None  None
# 26513      Drama         Thriller              NaN   None  None  None  None
# 26514    Fantasy           Action        Adventure   None  None  None  None
# 26515     Family        Adventure           Action   None  None  None  None
# 26516   Thriller           Horror              NaN   None  None  None  None
#
# [26517 rows x 7 columns]

# %%
df2[3]=df2[3].map(new_dict)
df2
# Out:
#                0                1                2       3     4     5     6
# 0      Adventure          Fantasy           Family     NaN  None  None  None
# 1        Fantasy        Adventure        Animation  Family  None  None  None
# 2      Adventure           Action  Science Fiction     NaN  None  None  None
# 3      Animation           Comedy           Family     NaN  None  None  None
# 4         Action  Science Fiction        Adventure     NaN  None  None  None
# ...          ...              ...              ...     ...   ...   ...   ...
# 26512     Horror            Drama              NaN     NaN  None  None  None
# 26513      Drama         Thriller              NaN     NaN  None  None  None
# 26514    Fantasy           Action        Adventure     NaN  None  None  None
# 26515     Family        Adventure           Action     NaN  None  None  None
# 26516   Thriller           Horror              NaN     NaN  None  None  None
#
# [26517 rows x 7 columns]

# %%
df2[4]=df2[4].map(new_dict)
df2
# Out:
#                0                1                2       3    4     5     6
# 0      Adventure          Fantasy           Family     NaN  NaN  None  None
# 1        Fantasy        Adventure        Animation  Family  NaN  None  None
# 2      Adventure           Action  Science Fiction     NaN  NaN  None  None
# 3      Animation           Comedy           Family     NaN  NaN  None  None
# 4         Action  Science Fiction        Adventure     NaN  NaN  None  None
# ...          ...              ...              ...     ...  ...   ...   ...
# 26512     Horror            Drama              NaN     NaN  NaN  None  None
# 26513      Drama         Thriller              NaN     NaN  NaN  None  None
# 26514    Fantasy           Action        Adventure     NaN  NaN  None  None
# 26515     Family        Adventure           Action     NaN  NaN  None  None
# 26516   Thriller           Horror              NaN     NaN  NaN  None  None
#
# [26517 rows x 7 columns]

# %%
df2[5]=df2[5].map(new_dict)
df2
# Out:
#                0                1                2       3    4    5     6
# 0      Adventure          Fantasy           Family     NaN  NaN  NaN  None
# 1        Fantasy        Adventure        Animation  Family  NaN  NaN  None
# 2      Adventure           Action  Science Fiction     NaN  NaN  NaN  None
# 3      Animation           Comedy           Family     NaN  NaN  NaN  None
# 4         Action  Science Fiction        Adventure     NaN  NaN  NaN  None
# ...          ...              ...              ...     ...  ...  ...   ...
# 26512     Horror            Drama              NaN     NaN  NaN  NaN  None
# 26513      Drama         Thriller              NaN     NaN  NaN  NaN  None
# 26514    Fantasy           Action        Adventure     NaN  NaN  NaN  None
# 26515     Family        Adventure           Action     NaN  NaN  NaN  None
# 26516   Thriller           Horror              NaN     NaN  NaN  NaN  None
#
# [26517 rows x 7 columns]

# %%
df2[6]=df2[6].map(new_dict)
df2
# Out:
#                0                1                2       3    4    5    6
# 0      Adventure          Fantasy           Family     NaN  NaN  NaN  NaN
# 1        Fantasy        Adventure        Animation  Family  NaN  NaN  NaN
# 2      Adventure           Action  Science Fiction     NaN  NaN  NaN  NaN
# 3      Animation           Comedy           Family     NaN  NaN  NaN  NaN
# 4         Action  Science Fiction        Adventure     NaN  NaN  NaN  NaN
# ...          ...              ...              ...     ...  ...  ...  ...
# 26512     Horror            Drama              NaN     NaN  NaN  NaN  NaN
# 26513      Drama         Thriller              NaN     NaN  NaN  NaN  NaN
# 26514    Fantasy           Action        Adventure     NaN  NaN  NaN  NaN
# 26515     Family        Adventure           Action     NaN  NaN  NaN  NaN
# 26516   Thriller           Horror              NaN     NaN  NaN  NaN  NaN
#
# [26517 rows x 7 columns]

# %%
df2
# Out:
#                0                1                2       3    4    5    6
# 0      Adventure          Fantasy           Family     NaN  NaN  NaN  NaN
# 1        Fantasy        Adventure        Animation  Family  NaN  NaN  NaN
# 2      Adventure           Action  Science Fiction     NaN  NaN  NaN  NaN
# 3      Animation           Comedy           Family     NaN  NaN  NaN  NaN
# 4         Action  Science Fiction        Adventure     NaN  NaN  NaN  NaN
# ...          ...              ...              ...     ...  ...  ...  ...
# 26512     Horror            Drama              NaN     NaN  NaN  NaN  NaN
# 26513      Drama         Thriller              NaN     NaN  NaN  NaN  NaN
# 26514    Fantasy           Action        Adventure     NaN  NaN  NaN  NaN
# 26515     Family        Adventure           Action     NaN  NaN  NaN  NaN
# 26516   Thriller           Horror              NaN     NaN  NaN  NaN  NaN
#
# [26517 rows x 7 columns]

# %%
domesticdf = pd.read_csv('domesticdf.csv')

# %%
domesticdf
# Out:
#                                             movie  production_budget  \
# 0            Star Wars Ep. VII: The Force Awakens          306000000
# 1                                   Black Panther          200000000
# 2                                         Titanic          200000000
# 3                    Star Wars Ep. IV: A New Hope           11000000
# 4                                  Jurassic World          215000000
# ...                                           ...                ...
# 5777                                   Battleship          220000000
# 5778  Pirates of the Caribbean: On Stranger Tides          410600000
# 5779                              The Lone Ranger          275000000
# 5780                                  John Carter          275000000
# 5781                                 Dark Phoenix          350000000
#
#       domestic_gross  production_profit_domestic
# 0          936662225                   630662225
# 1          700059566                   500059566
# 2          659363944                   459363944
# 3          460998007                   449998007
# 4          652270625                   437270625
# ...              ...                         ...
# 5777        65233400                  -154766600
# 5778       241063875                  -169536125
# 5779        89302115                  -185697885
# 5780        73058679                  -201941321
# 5781        42762350                  -307237650
#
# [5782 rows x 4 columns]

# %%
# df.merge(top_int_100, left_on='movie', right_on='original_title')

# %%
df.merge(domesticdf, left_on='original_title', right_on='movie')
# Out:
#       Unnamed: 0            genre_ids      id original_language  \
# 0              1  [14, 12, 16, 10751]   10191                en
# 1              2        [12, 28, 878]   10138                en
# 2              3      [16, 35, 10751]     862                en
# 3           2473      [16, 35, 10751]     862                en
# 4              4        [28, 878, 12]   27205                en
# ...          ...                  ...     ...               ...
# 2311       26323                   []  509316                en
# 2312       26425              [10402]  509306                en
# 2313       26092             [35, 16]  546674                en
# 2314       26322                   []  513161                en
# 2315       26508                 [16]  514492                en
#
#                 original_title  popularity release_date  \
# 0     How to Train Your Dragon      28.734   2010-03-26
# 1                   Iron Man 2      28.515   2010-05-07
# 2                    Toy Story      28.005   1995-11-22
# 3                    Toy Story      28.005   1995-11-22
# 4                    Inception      27.920   2010-07-16
# ...                        ...         ...          ...
# 2311                   The Box       0.600   2018-03-04
# 2312                   The Box       0.600   2018-03-04
# 2313                    Enough       0.719   2018-03-22
# 2314              Undiscovered       0.600   2018-04-07
# 2315                      Jaws       0.600   2018-05-29
#
#                          title  vote_average  vote_count  \
# 0     How to Train Your Dragon           7.7        7610
# 1                   Iron Man 2           6.8       12368
# 2                    Toy Story           7.9       10174
# 3                    Toy Story           7.9       10174
# 4                    Inception           8.3       22186
# ...                        ...           ...         ...
# 2311                   The Box           8.0           1
# 2312                   The Box           6.0           1
# 2313                    Enough           8.7           3
# 2314              Undiscovered           8.0           1
# 2315                      Jaws           0.0           1
#
#                          movie  production_budget  domestic_gross  \
# 0     How to Train Your Dragon          165000000       217581232
# 1                   Iron Man 2          170000000       312433331
# 2                    Toy Story           30000000       191796233
# 3                    Toy Story           30000000       191796233
# 4                    Inception          160000000       292576195
# ...                        ...                ...             ...
# 2311                   The Box           25000000        15051977
# 2312                   The Box           25000000        15051977
# 2313                    Enough           38000000        39177215
# 2314              Undiscovered            9000000         1069318
# 2315                      Jaws           12000000       260000000
#
#       production_profit_domestic
# 0                       52581232
# 1                      142433331
# 2                      161796233
# 3                      161796233
# 4                      132576195
# ...                          ...
# 2311                    -9948023
# 2312                    -9948023
# 2313                     1177215
# 2314                    -7930682
# 2315                   248000000
#
# [2316 rows x 14 columns]

# %%
df
# Out:
#        Unnamed: 0            genre_ids      id original_language  \
# 0               0      [12, 14, 10751]   12444                en
# 1               1  [14, 12, 16, 10751]   10191                en
# 2               2        [12, 28, 878]   10138                en
# 3               3      [16, 35, 10751]     862                en
# 4               4        [28, 878, 12]   27205                en
# ...           ...                  ...     ...               ...
# 26512       26512             [27, 18]  488143                en
# 26513       26513             [18, 53]  485975                en
# 26514       26514         [14, 28, 12]  381231                en
# 26515       26515      [10751, 12, 28]  366854                en
# 26516       26516             [53, 27]  309885                en
#
#                                      original_title  popularity release_date  \
# 0      Harry Potter and the Deathly Hallows: Part 1      33.533   2010-11-19
# 1                          How to Train Your Dragon      28.734   2010-03-26
# 2                                        Iron Man 2      28.515   2010-05-07
# 3                                         Toy Story      28.005   1995-11-22
# 4                                         Inception      27.920   2010-07-16
# ...                                             ...         ...          ...
# 26512                         Laboratory Conditions       0.600   2018-10-13
# 26513                               _EXHIBIT_84xxx_       0.600   2018-05-01
# 26514                                  The Last One       0.600   2018-10-01
# 26515                                  Trailer Made       0.600   2018-06-22
# 26516                                    The Church       0.600   2018-10-05
#
#                                               title  vote_average  vote_count
# 0      Harry Potter and the Deathly Hallows: Part 1           7.7       10788
# 1                          How to Train Your Dragon           7.7        7610
# 2                                        Iron Man 2           6.8       12368
# 3                                         Toy Story           7.9       10174
# 4                                         Inception           8.3       22186
# ...                                             ...           ...         ...
# 26512                         Laboratory Conditions           0.0           1
# 26513                               _EXHIBIT_84xxx_           0.0           1
# 26514                                  The Last One           0.0           1
# 26515                                  Trailer Made           0.0           1
# 26516                                    The Church           0.0           1
#
# [26517 rows x 10 columns]

# %%
# Genre Code Breaker-
# '{"genres":[{"id":28,"name":"Action"},{"id":12,"name":"Adventure"},{"id":16,"name":"Animation"},{"id":35,"name":"Comedy"},{"id":80,"name":"Crime"},{"id":99,"name":"Documentary"},{"id":18,"name":"Drama"},{"id":10751,"name":"Family"},{"id":14,"name":"Fantasy"},{"id":36,"name":"History"},{"id":27,"name":"Horror"},{"id":10402,"name":"Music"},{"id":9648,"name":"Mystery"},{"id":10749,"name":"Romance"},{"id":878,"name":"Science Fiction"},{"id":10770,"name":"TV Movie"},{"id":53,"name":"Thriller"},{"id":10752,"name":"War"},{"id":37,"name":"Western"}]}'

# %%
df2.to_csv('genres.csv', index=False)
