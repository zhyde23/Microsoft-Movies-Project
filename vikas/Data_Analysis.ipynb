# %%
import pandas as pd
from glob import glob

# %%
csv_files = glob('./All Data Files/*.csv')
csv_files
# Out:
# ['./All Data Files/tmdb.movies.csv',
#  './All Data Files/title.crew.csv',
#  './All Data Files/title.basics.csv',
#  './All Data Files/tn.movie_budgets.csv',
#  './All Data Files/name.basics.csv',
#  './All Data Files/title.akas.csv',
#  './All Data Files/bom.movie_gross.csv',
#  './All Data Files/title.principals.csv',
#  './All Data Files/title.ratings.csv']

# %%
data_csv = {}
for file in csv_files:
    data_csv[file] = pd.read_csv(file)

type(data_csv)
# Out:
# dict

# %%
df_1 = data_csv['./All Data Files/tmdb.movies.csv']
df_2 = data_csv['./All Data Files/title.crew.csv']
df_3 = data_csv['./All Data Files/title.basics.csv']
df_4 = data_csv['./All Data Files/tn.movie_budgets.csv']
df_5 = data_csv['./All Data Files/name.basics.csv']
df_6 = data_csv['./All Data Files/title.akas.csv']
df_7 = data_csv['./All Data Files/bom.movie_gross.csv']
df_8 = data_csv['./All Data Files/title.principals.csv']
df_9 = data_csv['./All Data Files/title.ratings.csv']

# %%
df_3_cleaned = pd.read_csv('df_3_cleaned.csv')

# %%
df_3_cleaned.isna().sum()
# Out:
# tconst             0
# primary_title      0
# original_title     0
# start_year         0
# runtime_minutes    0
# genres             0
# dtype: int64

# %%
df_5
# Out:
#            nconst         primary_name  birth_year  death_year  \
# 0       nm0061671    Mary Ellen Bauder         NaN         NaN
# 1       nm0061865         Joseph Bauer         NaN         NaN
# 2       nm0062070           Bruce Baum         NaN         NaN
# 3       nm0062195         Axel Baumann         NaN         NaN
# 4       nm0062798          Pete Baxter         NaN         NaN
# ...           ...                  ...         ...         ...
# 606643  nm9990381         Susan Grobes         NaN         NaN
# 606644  nm9990690          Joo Yeon So         NaN         NaN
# 606645  nm9991320       Madeline Smith         NaN         NaN
# 606646  nm9991786  Michelle Modigliani         NaN         NaN
# 606647  nm9993380       Pegasus Envoyé         NaN         NaN
#
#                                       primary_profession  \
# 0              miscellaneous,production_manager,producer
# 1             composer,music_department,sound_department
# ...

# %%
df_5.isna().sum()
# Out:
# nconst                     0
# primary_name               0
# birth_year            523912
# death_year            599865
# primary_profession     51340
# known_for_titles       30204
# dtype: int64

# %%
df_5_cleaned = df_5.drop('birth_year', axis=1)

# %%
df_5_cleaned = df_5_cleaned.drop('death_year', axis=1)

# %%
df_5_cleaned
# Out:
#            nconst         primary_name  \
# 0       nm0061671    Mary Ellen Bauder
# 1       nm0061865         Joseph Bauer
# 2       nm0062070           Bruce Baum
# 3       nm0062195         Axel Baumann
# 4       nm0062798          Pete Baxter
# ...           ...                  ...
# 606643  nm9990381         Susan Grobes
# 606644  nm9990690          Joo Yeon So
# 606645  nm9991320       Madeline Smith
# 606646  nm9991786  Michelle Modigliani
# 606647  nm9993380       Pegasus Envoyé
#
#                                       primary_profession  \
# 0              miscellaneous,production_manager,producer
# 1             composer,music_department,sound_department
# 2                             miscellaneous,actor,writer
# 3       camera_department,cinematographer,art_department
# 4       production_designer,art_department,set_decorator
# ...                                                  ...
# 606643                                           actress
# ...

# %%
df_5_cleaned.shape
# Out:
# (606648, 4)

# %%
df_5_cleaned.dropna(inplace=True)

# %%
df_5_cleaned.to_csv('df_5_cleaned.csv')

# %%
df_5_cleaned['tconst'] = df_5_cleaned['known_for_titles'].map(lambda x: x.split(','))

# %%
df_5_cleaned.drop('known_for_titles', axis=1, inplace=True)

# %%
df_5_cleaned
# Out:
#            nconst        primary_name  \
# 0       nm0061671   Mary Ellen Bauder
# 1       nm0061865        Joseph Bauer
# 2       nm0062070          Bruce Baum
# 3       nm0062195        Axel Baumann
# 4       nm0062798         Pete Baxter
# ...           ...                 ...
# 606639  nm9989840  Mariya Shekaturova
# 606640  nm9989854        Layla Louise
# 606644  nm9990690         Joo Yeon So
# 606645  nm9991320      Madeline Smith
# 606647  nm9993380      Pegasus Envoyé
#
#                                       primary_profession  \
# 0              miscellaneous,production_manager,producer
# 1             composer,music_department,sound_department
# 2                             miscellaneous,actor,writer
# 3       camera_department,cinematographer,art_department
# 4       production_designer,art_department,set_decorator
# ...                                                  ...
# 606639                                             actor
# ...

# %%
df_5_cleaned = df_5_cleaned.explode('tconst')

# %%
df_5_cleaned
# Out:
#            nconst       primary_name  \
# 0       nm0061671  Mary Ellen Bauder
# 0       nm0061671  Mary Ellen Bauder
# 0       nm0061671  Mary Ellen Bauder
# 0       nm0061671  Mary Ellen Bauder
# 1       nm0061865       Joseph Bauer
# ...           ...                ...
# 606644  nm9990690        Joo Yeon So
# 606644  nm9990690        Joo Yeon So
# 606645  nm9991320     Madeline Smith
# 606645  nm9991320     Madeline Smith
# 606647  nm9993380     Pegasus Envoyé
#
#                                 primary_profession     tconst
# 0        miscellaneous,production_manager,producer  tt0837562
# 0        miscellaneous,production_manager,producer  tt2398241
# 0        miscellaneous,production_manager,producer  tt0844471
# 0        miscellaneous,production_manager,producer  tt0118553
# 1       composer,music_department,sound_department  tt0896534
# ...                                            ...        ...
# 606644                                     actress  tt9090932
# ...

# %%
df_combined = df_5_cleaned.set_index('tconst').join(df_3_cleaned.set_index('tconst'))

# %%
df_combined
# Out:
#               nconst            primary_name  \
# tconst
# tt0000014  nm0166380          François Clerc
# tt0000014  nm0244989            Benoît Duval
# tt0000038  nm2958402          Scott Stratton
# tt0000091  nm0617588          Georges Méliès
# tt0000229  nm0595213               Ben Model
# ...              ...                     ...
# tt9916754  nm9275317            Fábio Ferraz
# tt9916754  nm9272490           Angela Gurgel
# tt9916754  nm8349149  Vinicius Augusto Bozzo
# tt9916754  nm9275320          Daniel Cardoso
# tt9916764  nm6687687        Meleisha Edwards
#
#                                     primary_profession  \
# tconst
# tt0000014                                        actor
# tt0000014                                        actor
# tt0000038                        actor,writer,composer
# tt0000091                      director,actor,producer
# tt0000229             composer,music_department,writer
# ...                                                ...
# ...

# %%
df_combined['original_title'].isna().sum()
# Out:
# 845500

# %%
df_combinedf_combined['original_title'].dropna(inplace=True)

# %%
df_combined.isna().sum()
# Out:
# nconst                     0
# primary_name               0
# primary_profession         0
# primary_title         845500
# original_title        845500
# start_year            845500
# runtime_minutes       845500
# genres                845500
# dtype: int64

# %%
df_combined.dropna(inplace=True)

# %%
df_combined
# Out:
#               nconst            primary_name  \
# tconst
# tt0063540  nm1194313          Mahasweta Devi
# tt0063540  nm1391276           Anjana Rawail
# tt0069049  nm0462648               Oja Kodar
# tt0069049  nm0613657            Bob Murawski
# tt0069049  nm1152466            Tom Callaway
# ...              ...                     ...
# tt9916754  nm9272748       Cristiano Freitas
# tt9916754  nm9275317            Fábio Ferraz
# tt9916754  nm9272490           Angela Gurgel
# tt9916754  nm8349149  Vinicius Augusto Bozzo
# tt9916754  nm9275320          Daniel Cardoso
#
#                                     primary_profession  \
# tconst
# tt0063540                                       writer
# tt0063540                      writer,costume_designer
# tt0069049                      actress,writer,director
# tt0069049         editor,producer,editorial_department
# tt0069049            cinematographer,camera_department
# ...                                                ...
# ...

# %%
df_4
# Out:
#       id  release_date                                        movie  \
# 0      1  Dec 18, 2009                                       Avatar
# 1      2  May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 2      3   Jun 7, 2019                                 Dark Phoenix
# 3      4   May 1, 2015                      Avengers: Age of Ultron
# 4      5  Dec 15, 2017            Star Wars Ep. VIII: The Last Jedi
# ...   ..           ...                                          ...
# 5777  78  Dec 31, 2018                                       Red 11
# 5778  79   Apr 2, 1999                                    Following
# 5779  80  Jul 13, 2005                Return to the Land of Wonders
# 5780  81  Sep 29, 2015                         A Plague So Pleasant
# 5781  82   Aug 5, 2005                            My Date With Drew
#
#      production_budget domestic_gross worldwide_gross
# 0         $425,000,000   $760,507,625  $2,776,345,279
# ...

# %%
df_com_clean.set_index('primary_title').join(df_4.set_index('movie'))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-85-783ef9ca3c8e> in <module>
# ----> 1 df_com_clean.set_index('primary_title').join(df_4.set_index('movie'))
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/pandas/core/frame.py in set_index(self, keys, drop, append, inplace, verify_integrity)
#    4301
#    4302         if missing:
# -> 4303             raise KeyError(f"None of {missing} are in the columns")
#    4304
#    4305         if inplace:
#
# KeyError: "None of ['primary_title'] are in the columns"

# %%
df_7
# Out:
#                                             title      studio  domestic_gross  \
# 0                                     Toy Story 3          BV     415000000.0
# 1                      Alice in Wonderland (2010)          BV     334200000.0
# 2     Harry Potter and the Deathly Hallows Part 1          WB     296000000.0
# 3                                       Inception          WB     292600000.0
# 4                             Shrek Forever After        P/DW     238700000.0
# ...                                           ...         ...             ...
# 3382                                    The Quake       Magn.          6200.0
# 3383                  Edward II (2018 re-release)          FM          4800.0
# 3384                                     El Pacto        Sony          2500.0
# 3385                                     The Swan  Synergetic          2400.0
# 3386                            An Actor Prepares       Grav.          1700.0
#
#      foreign_gross  year
# ...

# %%
df_3.set_index('movie').join(df_7.set_index('title'))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-96-25c1e2e9c012> in <module>
# ----> 1 df_3.set_index('movie').join(df_7.set_index('title'))
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/pandas/core/frame.py in set_index(self, keys, drop, append, inplace, verify_integrity)
#    4301
#    4302         if missing:
# -> 4303             raise KeyError(f"None of {missing} are in the columns")
#    4304
#    4305         if inplace:
#
# KeyError: "None of ['movie'] are in the columns"

# %%
df_1
# Out:
#        Unnamed: 0            genre_ids      id original_language  \
# 0               0      [12, 14, 10751]   12444                en
# 1               1  [14, 12, 16, 10751]   10191                en
# 2               2        [12, 28, 878]   10138                en
# 3               3      [16, 35, 10751]     862                en
# 4               4        [28, 878, 12]   27205                en
# ...           ...                  ...     ...               ...
# 26512       26512             [27, 18]  488143                en
# 26513       26513             [18, 53]  485975                en
# 26514       26514         [14, 28, 12]  381231                en
# 26515       26515      [10751, 12, 28]  366854                en
# 26516       26516             [53, 27]  309885                en
#
#                                      original_title  popularity release_date  \
# 0      Harry Potter and the Deathly Hallows: Part 1      33.533   2010-11-19
# ...

# %%
# Out:
#          title_id  ordering                                    title region  \
# 0       tt0369610        10                            Джурасик свят     BG
# 1       tt0369610        11                        Jurashikku warudo     JP
# 2       tt0369610        12  Jurassic World: O Mundo dos Dinossauros     BR
# 3       tt0369610        13                  O Mundo dos Dinossauros     BR
# 4       tt0369610        14                           Jurassic World     FR
# ...           ...       ...                                      ...    ...
# 331698  tt9827784         2                       Sayonara kuchibiru    NaN
# 331699  tt9827784         3                            Farewell Song    XWW
# 331700  tt9880178         1                              La atención    NaN
# 331701  tt9880178         2                              La atención     ES
# 331702  tt9880178         3                            The Attention    XWW
#
# ...
