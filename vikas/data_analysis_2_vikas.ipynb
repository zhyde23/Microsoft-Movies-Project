# %%
import pandas as pd
import numpy as np
from glob import glob 
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# # Taking a look at all the data files in the 'Data Cleaning' notebook, we'll go ahead with analyzing df_1, df_3, and df_4 in this notebook.

# %%
df_1 = pd.read_csv('df_1_cleaned.csv')
df_3 = pd.read_csv('df_3_cleaned.csv')
df_4 = pd.read_csv('df_4_cleaned_profits.csv')

# %% [markdown]
# #Preparing df_1 for analysis

# %%
df_1 = df_1.drop(['Unnamed: 0', 'Unnamed: 0.1', 'id'], axis=1)

# %%
df_1 = df_1.drop(['original_title'], axis=1)

# %%
df_1['title'] = df_1['title'].str.lower()

# %%
df_1 = df_1.rename(columns = {'title': 'movie'})

# %%
df_1
# Out:
#                  genre_ids original_language  popularity release_date  \
# 0          [12, 14, 10751]                en      33.533   2010-11-19
# 1      [14, 12, 16, 10751]                en      28.734   2010-03-26
# 2            [12, 28, 878]                en      28.515   2010-05-07
# 3          [16, 35, 10751]                en      28.005   1995-11-22
# 4            [28, 878, 12]                en      27.920   2010-07-16
# ...                    ...               ...         ...          ...
# 26512             [27, 18]                en       0.600   2018-10-13
# 26513             [18, 53]                en       0.600   2018-05-01
# 26514         [14, 28, 12]                en       0.600   2018-10-01
# 26515      [10751, 12, 28]                en       0.600   2018-06-22
# 26516             [53, 27]                en       0.600   2018-10-05
#
#                                               movie  vote_average  vote_count
# 0      harry potter and the deathly hallows: part 1           7.7       10788
# 1                          how to train your dragon           7.7        7610
# 2                                        iron man 2           6.8       12368
# 3                                         toy story           7.9       10174
# 4                                         inception           8.3       22186
# ...                                             ...           ...         ...
# 26512                         laboratory conditions           0.0           1
# 26513                               _exhibit_84xxx_           0.0           1
# 26514                                  the last one           0.0           1
# 26515                                  trailer made           0.0           1
# 26516                                    the church           0.0           1
#
# [26517 rows x 7 columns]

# %%
df_3
# Out:
#            tconst                                primary_title  \
# 0       tt0063540                                    Sunghursh
# 1       tt0066787              One Day Before the Rainy Season
# 2       tt0069049                   The Other Side of the Wind
# 3       tt0069204                              Sabse Bada Sukh
# 4       tt0100275                     The Wandering Soap Opera
# ...           ...                                          ...
# 140729  tt9916428                          The Secret of China
# 140730  tt9916538                          Kuambil Lagi Hatiku
# 140731  tt9916622  Rodolpho Teóphilo - O Legado de um Pioneiro
# 140732  tt9916706                              Dankyavar Danka
# 140733  tt9916754               Chico Albuquerque - Revelações
#
#                                      original_title  start_year  \
# 0                                         Sunghursh        2013
# 1                                   Ashad Ka Ek Din        2019
# 2                        The Other Side of the Wind        2018
# 3                                   Sabse Bada Sukh        2018
# 4                             La Telenovela Errante        2017
# ...                                             ...         ...
# 140729                          The Secret of China        2019
# 140730                          Kuambil Lagi Hatiku        2019
# 140731  Rodolpho Teóphilo - O Legado de um Pioneiro        2015
# 140732                              Dankyavar Danka        2013
# 140733               Chico Albuquerque - Revelações        2013
#
#         runtime_minutes                 genres
# 0                 175.0     Action,Crime,Drama
# 1                 114.0        Biography,Drama
# 2                 122.0                  Drama
# 3                  87.0           Comedy,Drama
# 4                  80.0   Comedy,Drama,Fantasy
# ...                 ...                    ...
# 140729             87.0  Adventure,History,War
# 140730            123.0                  Drama
# 140731             87.0            Documentary
# 140732             87.0                 Comedy
# 140733             87.0            Documentary
#
# [140734 rows x 6 columns]

# %%
# Converting 'primary_title' to lowercase for consistency. Also, dropping original_title to remove duplicate entries.

df_3['primary_title'] = df_3['primary_title'].str.lower()
df_3 = df_3.drop('original_title', axis=1)
df_3
# Out:
#            tconst                                primary_title  start_year  \
# 0       tt0063540                                    sunghursh        2013
# 1       tt0066787              one day before the rainy season        2019
# 2       tt0069049                   the other side of the wind        2018
# 3       tt0069204                              sabse bada sukh        2018
# 4       tt0100275                     the wandering soap opera        2017
# ...           ...                                          ...         ...
# 140729  tt9916428                          the secret of china        2019
# 140730  tt9916538                          kuambil lagi hatiku        2019
# 140731  tt9916622  rodolpho teóphilo - o legado de um pioneiro        2015
# 140732  tt9916706                              dankyavar danka        2013
# 140733  tt9916754               chico albuquerque - revelações        2013
#
#         runtime_minutes                 genres
# 0                 175.0     Action,Crime,Drama
# 1                 114.0        Biography,Drama
# 2                 122.0                  Drama
# 3                  87.0           Comedy,Drama
# 4                  80.0   Comedy,Drama,Fantasy
# ...                 ...                    ...
# 140729             87.0  Adventure,History,War
# 140730            123.0                  Drama
# 140731             87.0            Documentary
# 140732             87.0                 Comedy
# 140733             87.0            Documentary
#
# [140734 rows x 5 columns]

# %%
df_3 = df_3.rename(columns = {'primary_title': 'movie'})

# %%
df_3
# Out:
#            tconst                                        movie  start_year  \
# 0       tt0063540                                    sunghursh        2013
# 1       tt0066787              one day before the rainy season        2019
# 2       tt0069049                   the other side of the wind        2018
# 3       tt0069204                              sabse bada sukh        2018
# 4       tt0100275                     the wandering soap opera        2017
# ...           ...                                          ...         ...
# 140729  tt9916428                          the secret of china        2019
# 140730  tt9916538                          kuambil lagi hatiku        2019
# 140731  tt9916622  rodolpho teóphilo - o legado de um pioneiro        2015
# 140732  tt9916706                              dankyavar danka        2013
# 140733  tt9916754               chico albuquerque - revelações        2013
#
#         runtime_minutes                 genres
# 0                 175.0     Action,Crime,Drama
# 1                 114.0        Biography,Drama
# 2                 122.0                  Drama
# 3                  87.0           Comedy,Drama
# 4                  80.0   Comedy,Drama,Fantasy
# ...                 ...                    ...
# 140729             87.0  Adventure,History,War
# 140730            123.0                  Drama
# 140731             87.0            Documentary
# 140732             87.0                 Comedy
# 140733             87.0            Documentary
#
# [140734 rows x 5 columns]

# %%
df_4
# Out:
#       Unnamed: 0  id release_date  \
# 0              0   1   2009-12-18
# 1              1   2   2011-05-20
# 2              2   3   2019-06-07
# 3              3   4   2015-05-01
# 4              4   5   2017-12-15
# ...          ...  ..          ...
# 5777        5777  78   2018-12-31
# 5778        5778  79   1999-04-02
# 5779        5779  80   2005-07-13
# 5780        5780  81   2015-09-29
# 5781        5781  82   2005-08-05
#
#                                             movie  production_budget  \
# 0                                          avatar          425000000
# 1     pirates of the caribbean: on stranger tides          410600000
# 2                                    dark phoenix          350000000
# 3                         avengers: age of ultron          330600000
# 4               star wars ep. viii: the last jedi          317000000
# ...                                           ...                ...
# 5777                                       red 11               7000
# 5778                                    following               6000
# 5779                return to the land of wonders               5000
# 5780                         a plague so pleasant               1400
# 5781                            my date with drew               1100
#
#       domestic_gross  worldwide_gross  total_profit  \
# 0          760507625       2776345279    2351345279
# 1          241063875       1045663875     635063875
# 2           42762350        149762350    -200237650
# 3          459005868       1403013963    1072413963
# 4          620181382       1316721747     999721747
# ...              ...              ...           ...
# 5777               0                0         -7000
# 5778           48482           240495        234495
# 5779            1338             1338         -3662
# 5780               0                0         -1400
# 5781          181041           181041        179941
#
#       was_it_profitable_domestically
# 0                               True
# 1                              False
# 2                              False
# 3                               True
# 4                               True
# ...                              ...
# 5777                           False
# 5778                            True
# 5779                           False
# 5780                           False
# 5781                            True
#
# [5782 rows x 9 columns]

# %%
df_4 = df_4.drop('Unnamed: 0', axis=1)

# %%
df_4
# Out:
#       id release_date                                        movie  \
# 0      1   2009-12-18                                       avatar
# 1      2   2011-05-20  pirates of the caribbean: on stranger tides
# 2      3   2019-06-07                                 dark phoenix
# 3      4   2015-05-01                      avengers: age of ultron
# 4      5   2017-12-15            star wars ep. viii: the last jedi
# ...   ..          ...                                          ...
# 5777  78   2018-12-31                                       red 11
# 5778  79   1999-04-02                                    following
# 5779  80   2005-07-13                return to the land of wonders
# 5780  81   2015-09-29                         a plague so pleasant
# 5781  82   2005-08-05                            my date with drew
#
#       production_budget  domestic_gross  worldwide_gross  total_profit  \
# 0             425000000       760507625       2776345279    2351345279
# 1             410600000       241063875       1045663875     635063875
# 2             350000000        42762350        149762350    -200237650
# 3             330600000       459005868       1403013963    1072413963
# 4             317000000       620181382       1316721747     999721747
# ...                 ...             ...              ...           ...
# 5777               7000               0                0         -7000
# 5778               6000           48482           240495        234495
# 5779               5000            1338             1338         -3662
# 5780               1400               0                0         -1400
# 5781               1100          181041           181041        179941
#
#       was_it_profitable_domestically
# 0                               True
# 1                              False
# 2                              False
# 3                               True
# 4                               True
# ...                              ...
# 5777                           False
# 5778                            True
# 5779                           False
# 5780                           False
# 5781                            True
#
# [5782 rows x 8 columns]

# %%
#Creating a final Dataframe by joining df_1, df_3, and df_4. 
df_final = df_1.merge(df_3, on='movie').merge(df_4, on='movie')
df_final
# Out:
#                 genre_ids original_language  popularity release_date_x  \
# 0     [14, 12, 16, 10751]                en      28.734     2010-03-26
# 1           [12, 28, 878]                en      28.515     2010-05-07
# 2           [28, 878, 12]                en      27.920     2010-07-16
# 3         [12, 14, 10751]                en      26.691     2010-02-11
# 4       [28, 12, 14, 878]                en      26.526     2009-12-18
# ...                   ...               ...         ...            ...
# 4634              [10402]                en       0.600     2018-03-04
# 4635              [10402]                en       0.600     2018-03-04
# 4636              [10402]                en       0.600     2018-03-04
# 4637             [35, 16]                en       0.719     2018-03-22
# 4638             [35, 16]                en       0.719     2018-03-22
#
#                                                   movie  vote_average  \
# 0                              how to train your dragon           7.7
# 1                                            iron man 2           6.8
# 2                                             inception           8.3
# 3     percy jackson & the olympians: the lightning t...           6.1
# 4                                                avatar           7.4
# ...                                                 ...           ...
# 4634                                            the box           6.0
# 4635                                            the box           6.0
# 4636                                            the box           6.0
# 4637                                             enough           8.7
# 4638                                             enough           8.7
#
#       vote_count     tconst  start_year  runtime_minutes  \
# 0           7610  tt0892769        2010             98.0
# 1          12368  tt1228705        2010            124.0
# 2          22186  tt1375666        2010            148.0
# 3           4229  tt0814255        2010            118.0
# 4          18676  tt1775309        2011             93.0
# ...          ...        ...         ...              ...
# 4634           1  tt1728200        2011             89.0
# 4635           1  tt5047858        2015            100.0
# 4636           1  tt5678896        2018             56.0
# 4637           3  tt2926198        2013             96.0
# 4638           3  tt8382238        2017             87.0
#
#                           genres  id release_date_y  production_budget  \
# 0     Action,Adventure,Animation  30     2010-03-26          165000000
# 1        Action,Adventure,Sci-Fi  15     2010-05-07          170000000
# 2        Action,Adventure,Sci-Fi  38     2010-07-16          160000000
# 3       Adventure,Family,Fantasy  17     2010-02-12           95000000
# 4                         Horror   1     2009-12-18          425000000
# ...                          ...  ..            ...                ...
# 4634                       Drama  66     2009-11-06           25000000
# 4635                   Drama,War  66     2009-11-06           25000000
# 4636                    Thriller  66     2009-11-06           25000000
# 4637               Drama,History  68     2002-05-24           38000000
# 4638                       Drama  68     2002-05-24           38000000
#
#       domestic_gross  worldwide_gross  total_profit  \
# 0          217581232        494870992     329870992
# 1          312433331        621156389     451156389
# 2          292576195        835524642     675524642
# 3           88768303        223050874     128050874
# 4          760507625       2776345279    2351345279
# ...              ...              ...           ...
# 4634        15051977         34356760       9356760
# 4635        15051977         34356760       9356760
# 4636        15051977         34356760       9356760
# 4637        39177215         50970660      12970660
# 4638        39177215         50970660      12970660
#
#       was_it_profitable_domestically
# 0                               True
# 1                               True
# 2                               True
# 3                              False
# 4                               True
# ...                              ...
# 4634                           False
# 4635                           False
# 4636                           False
# 4637                            True
# 4638                            True
#
# [4639 rows x 18 columns]

# %%
df_final.to_csv('final_analysis_file.csv')

# %%
# Dropping non-needed columns from df_final
df_final = df_final.drop(['genre_ids', 'release_date_x', 'id', 'tconst'], axis=1)
df_final
# Out:
#      original_language  popularity  \
# 0                   en      28.734
# 1                   en      28.515
# 2                   en      27.920
# 3                   en      26.691
# 4                   en      26.526
# ...                ...         ...
# 4634                en       0.600
# 4635                en       0.600
# 4636                en       0.600
# 4637                en       0.719
# 4638                en       0.719
#
#                                                   movie  vote_average  \
# 0                              how to train your dragon           7.7
# 1                                            iron man 2           6.8
# 2                                             inception           8.3
# 3     percy jackson & the olympians: the lightning t...           6.1
# 4                                                avatar           7.4
# ...                                                 ...           ...
# 4634                                            the box           6.0
# 4635                                            the box           6.0
# 4636                                            the box           6.0
# 4637                                             enough           8.7
# 4638                                             enough           8.7
#
#       vote_count  start_year  runtime_minutes                      genres  \
# 0           7610        2010             98.0  Action,Adventure,Animation
# 1          12368        2010            124.0     Action,Adventure,Sci-Fi
# 2          22186        2010            148.0     Action,Adventure,Sci-Fi
# 3           4229        2010            118.0    Adventure,Family,Fantasy
# 4          18676        2011             93.0                      Horror
# ...          ...         ...              ...                         ...
# 4634           1        2011             89.0                       Drama
# 4635           1        2015            100.0                   Drama,War
# 4636           1        2018             56.0                    Thriller
# 4637           3        2013             96.0               Drama,History
# 4638           3        2017             87.0                       Drama
#
#      release_date_y  production_budget  domestic_gross  worldwide_gross  \
# 0        2010-03-26          165000000       217581232        494870992
# 1        2010-05-07          170000000       312433331        621156389
# 2        2010-07-16          160000000       292576195        835524642
# 3        2010-02-12           95000000        88768303        223050874
# 4        2009-12-18          425000000       760507625       2776345279
# ...             ...                ...             ...              ...
# 4634     2009-11-06           25000000        15051977         34356760
# 4635     2009-11-06           25000000        15051977         34356760
# 4636     2009-11-06           25000000        15051977         34356760
# 4637     2002-05-24           38000000        39177215         50970660
# 4638     2002-05-24           38000000        39177215         50970660
#
#       total_profit  was_it_profitable_domestically
# 0        329870992                            True
# 1        451156389                            True
# 2        675524642                            True
# 3        128050874                           False
# 4       2351345279                            True
# ...            ...                             ...
# 4634       9356760                           False
# 4635       9356760                           False
# 4636       9356760                           False
# 4637      12970660                            True
# 4638      12970660                            True
#
# [4639 rows x 14 columns]

# %%
df_final = df_final.drop(['start_year', 'runtime_minutes'], axis=1)

# %%
df_final = df_final.drop_duplicates(subset = 'movie', keep='first')

# %%
df_final
# Out:
#      original_language  popularity  \
# 0                   en      28.734
# 1                   en      28.515
# 2                   en      27.920
# 3                   en      26.691
# 4                   en      26.526
# ...                ...         ...
# 4611                en       1.836
# 4613                en       1.816
# 4619                en       1.400
# 4622                en       0.840
# 4637                en       0.719
#
#                                                   movie  vote_average  \
# 0                              how to train your dragon           7.7
# 1                                            iron man 2           6.8
# 2                                             inception           8.3
# 3     percy jackson & the olympians: the lightning t...           6.1
# 4                                                avatar           7.4
# ...                                                 ...           ...
# 4611                                        bad company          10.0
# 4613                                                  3           6.0
# 4619                                              molly           5.8
# 4622                                            the box           8.0
# 4637                                             enough           8.7
#
#       vote_count                      genres release_date_y  \
# 0           7610  Action,Adventure,Animation     2010-03-26
# 1          12368     Action,Adventure,Sci-Fi     2010-05-07
# 2          22186     Action,Adventure,Sci-Fi     2010-07-16
# 3           4229    Adventure,Family,Fantasy     2010-02-12
# 4          18676                      Horror     2009-12-18
# ...          ...                         ...            ...
# 4611           1                    Thriller     2002-06-07
# 4613           2        Comedy,Drama,Romance     2011-09-16
# 4619           5               Action,Sci-Fi     1999-10-22
# 4622           1                       Drama     2009-11-06
# 4637           3               Drama,History     2002-05-24
#
#       production_budget  domestic_gross  worldwide_gross  total_profit  \
# 0             165000000       217581232        494870992     329870992
# 1             170000000       312433331        621156389     451156389
# 2             160000000       292576195        835524642     675524642
# 3              95000000        88768303        223050874     128050874
# 4             425000000       760507625       2776345279    2351345279
# ...                 ...             ...              ...           ...
# 4611           70000000        30157016         69157016       -842984
# 4613            7200000           59774           295492      -6904508
# 4619           21000000           17396            17396     -20982604
# 4622           25000000        15051977         34356760       9356760
# 4637           38000000        39177215         50970660      12970660
#
#       was_it_profitable_domestically
# 0                               True
# 1                               True
# 2                               True
# 3                              False
# 4                               True
# ...                              ...
# 4611                           False
# 4613                           False
# 4619                           False
# 4622                           False
# 4637                            True
#
# [1834 rows x 12 columns]

# %%
#Plotting Profits vs Production Budget to visualize the relationship

# %%
fig, ax = plt.subplots()
fig.set_size_inches(15,10)
x = df_final['production_budget']
y = df_final['total_profit']
df = pd.DataFrame({'x': df_final['production_budget'], 'y': df_final['total_profit']})
plt.xlabel('Production Budget (Billions)', fontsize = 18, weight = 'bold')
plt.ylabel('Profit (Millions)', fontsize = 18, weight = 'bold')
ax.scatter(df.x, df.y, c=np.sign(df.y))
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %% [markdown]
# #Adding Month of Release column to try and visualize the relationship of release date and gross revenue.

# %%
df_final['month_of_release'] = pd.DatetimeIndex(df_final['release_date_y']).month
df_final
# Out:
#      original_language  popularity  \
# 0                   en      28.734
# 1                   en      28.515
# 2                   en      27.920
# 3                   en      26.691
# 4                   en      26.526
# ...                ...         ...
# 4611                en       1.836
# 4613                en       1.816
# 4619                en       1.400
# 4622                en       0.840
# 4637                en       0.719
#
#                                                   movie  vote_average  \
# 0                              how to train your dragon           7.7
# 1                                            iron man 2           6.8
# 2                                             inception           8.3
# 3     percy jackson & the olympians: the lightning t...           6.1
# 4                                                avatar           7.4
# ...                                                 ...           ...
# 4611                                        bad company          10.0
# 4613                                                  3           6.0
# 4619                                              molly           5.8
# 4622                                            the box           8.0
# 4637                                             enough           8.7
#
#       vote_count                      genres release_date_y  \
# 0           7610  Action,Adventure,Animation     2010-03-26
# 1          12368     Action,Adventure,Sci-Fi     2010-05-07
# 2          22186     Action,Adventure,Sci-Fi     2010-07-16
# 3           4229    Adventure,Family,Fantasy     2010-02-12
# 4          18676                      Horror     2009-12-18
# ...          ...                         ...            ...
# 4611           1                    Thriller     2002-06-07
# 4613           2        Comedy,Drama,Romance     2011-09-16
# 4619           5               Action,Sci-Fi     1999-10-22
# 4622           1                       Drama     2009-11-06
# 4637           3               Drama,History     2002-05-24
#
#       production_budget  domestic_gross  worldwide_gross  total_profit  \
# 0             165000000       217581232        494870992     329870992
# 1             170000000       312433331        621156389     451156389
# 2             160000000       292576195        835524642     675524642
# 3              95000000        88768303        223050874     128050874
# 4             425000000       760507625       2776345279    2351345279
# ...                 ...             ...              ...           ...
# 4611           70000000        30157016         69157016       -842984
# 4613            7200000           59774           295492      -6904508
# 4619           21000000           17396            17396     -20982604
# 4622           25000000        15051977         34356760       9356760
# 4637           38000000        39177215         50970660      12970660
#
#       was_it_profitable_domestically  month_of_release
# 0                               True                 3
# 1                               True                 5
# 2                               True                 7
# 3                              False                 2
# 4                               True                12
# ...                              ...               ...
# 4611                           False                 6
# 4613                           False                 9
# 4619                           False                10
# 4622                           False                11
# 4637                            True                 5
#
# [1834 rows x 13 columns]

# %%
df_final['genres'].value_counts()
# Out:
# Drama                         104
# Comedy,Drama,Romance           67
# Adventure,Animation,Comedy     65
# Comedy,Drama                   64
# Comedy                         62
#                              ...
# Adventure,Horror                1
# Family,Fantasy,Music            1
# Comedy,Fantasy,Romance          1
# Adventure,Drama,History         1
# Biography,Drama,War             1
# Name: genres, Length: 267, dtype: int64

# %% [markdown]
# #Creating a new Dataframe monthly_gross to start preparing for the bar graph.

# %%
monthly_gross = df_final[['month_of_release', 'worldwide_gross']]

# %%
monthly_gross = monthly_gross.rename(columns = {'worldwide_gross': 'Worldwide_Gross (In Millions)'})
monthly_gross
# Out:
#       month_of_release  Worldwide_Gross (In Millions)
# 0                    3                      494870992
# 1                    5                      621156389
# 2                    7                      835524642
# 3                    2                      223050874
# 4                   12                     2776345279
# ...                ...                            ...
# 4611                 6                       69157016
# 4613                 9                         295492
# 4619                10                          17396
# 4622                11                       34356760
# 4637                 5                       50970660
#
# [1834 rows x 2 columns]

# %%
monthly_gross['Worldwide_Gross (In Millions)'] = monthly_gross['Worldwide_Gross (In Millions)'].map( lambda x: x/1000000)

# %% [markdown]
# #Creating a new Dataframe to show month-wise average Worldwide Gross. This dataframe will be used for the bar chart.

# %%
average_monthly_gross = monthly_gross.groupby('month_of_release', as_index=False).mean()

# %%
average_monthly_gross
# Out:
#     month_of_release  Worldwide_Gross (In Millions)
# 0                  1                      66.482098
# 1                  2                     100.530081
# 2                  3                     113.118639
# 3                  4                     101.332656
# 4                  5                     191.359998
# 5                  6                     212.193042
# 6                  7                     166.307980
# 7                  8                      79.204087
# 8                  9                      62.144174
# 9                 10                      71.587905
# 10                11                     175.355633
# 11                12                     128.922554

# %%
df_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1834 entries, 0 to 4637
# Data columns (total 13 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   original_language               1834 non-null   object
#  1   popularity                      1834 non-null   float64
#  2   movie                           1834 non-null   object
#  3   vote_average                    1834 non-null   float64
#  4   vote_count                      1834 non-null   int64
#  5   genres                          1834 non-null   object
#  6   release_date_y                  1834 non-null   object
#  7   production_budget               1834 non-null   int64
#  8   domestic_gross                  1834 non-null   int64
#  9   worldwide_gross                 1834 non-null   int64
#  10  total_profit                    1834 non-null   int64
#  11  was_it_profitable_domestically  1834 non-null   bool
#  12  month_of_release                1834 non-null   int64
# dtypes: bool(1), float64(2), int64(6), object(4)
# memory usage: 188.1+ KB

# %%
fig, ax = plt.subplots()
fig.set_size_inches(20,10)
palette = sns.color_palette("GnBu_d", 2)
ax = sns.lineplot(x= 'month_of_release', y = 'Worldwide_Gross (In Millions)', marker= 'o',palette = palette,  ci=0, markersize = 15, data= average_monthly_gross)
plt.yticks(ax.get_yticks(), ax.get_yticks())
plt.ylabel('Average Movie Gross Revenue (Millions)', fontsize=20, weight='bold')
plt.xlabel('Months', fontsize = 20, weight='bold')
sns.set(style = 'whitegrid', font_scale = 1)
plt.show()

# %%
df_final.loc[df_final['genres'].str.contains(','), 'genres'] = 'several'
genre_graph_data = df_final.groupby('genres', as_index=False)['worldwide_gross'].mean()
genre_graph_data = genre_graph_data.sort_values(by='worldwide_gross', ascending=True)
genre_graph_data
# Out:
#          genres  worldwide_gross
# 10        Music     1.300000e+01
# 7        Family     9.900000e+03
# 14      Western     1.456879e+06
# 8       Fantasy     1.739150e+07
# 13     Thriller     2.571033e+07
# 6         Drama     3.445003e+07
# 5   Documentary     3.627777e+07
# 0        Action     6.096726e+07
# 3        Comedy     6.153091e+07
# 4         Crime     9.962487e+07
# 9        Horror     1.194058e+08
# 15      several     1.328004e+08
# 11      Musical     1.910826e+08
# 12       Sci-Fi     3.034499e+08
# 2     Animation     3.289214e+08
# 1     Adventure     4.984382e+08

# %%
sns.set(font_scale = 1)
fig, ax = plt.subplots()
fig.set_size_inches(40,25)
pal = sns.color_palette('GnBu_d', len(genre_graph_data))
ax = sns.barplot(x='genres', y='worldwide_gross', ci=None, palette=np.array(pal[: :]), data=genre_graph_data)
plt.xlabel('Movie Genres', fontsize=40, weight='bold')
plt.ylabel('Average Gross Revenue for Movies (in Millions of US$)', fontsize=40, weight='bold')
plt.yticks(ax.get_yticks(), ax.get_yticks()/1000000)
plt.tick_params(axis='both', which='major', labelsize=20)
plt.show()

# %%
df_final
# Out:
#      original_language  popularity  \
# 0                   en      28.734
# 1                   en      28.515
# 2                   en      27.920
# 3                   en      26.691
# 4                   en      26.526
# ...                ...         ...
# 4611                en       1.836
# 4613                en       1.816
# 4619                en       1.400
# 4622                en       0.840
# 4637                en       0.719
#
#                                                   movie  vote_average  \
# 0                              how to train your dragon           7.7
# 1                                            iron man 2           6.8
# 2                                             inception           8.3
# 3     percy jackson & the olympians: the lightning t...           6.1
# 4                                                avatar           7.4
# ...                                                 ...           ...
# 4611                                        bad company          10.0
# 4613                                                  3           6.0
# 4619                                              molly           5.8
# 4622                                            the box           8.0
# 4637                                             enough           8.7
#
#       vote_count    genres release_date_y  production_budget  domestic_gross  \
# 0           7610   several     2010-03-26          165000000       217581232
# 1          12368   several     2010-05-07          170000000       312433331
# 2          22186   several     2010-07-16          160000000       292576195
# 3           4229   several     2010-02-12           95000000        88768303
# 4          18676    Horror     2009-12-18          425000000       760507625
# ...          ...       ...            ...                ...             ...
# 4611           1  Thriller     2002-06-07           70000000        30157016
# 4613           2   several     2011-09-16            7200000           59774
# 4619           5   several     1999-10-22           21000000           17396
# 4622           1     Drama     2009-11-06           25000000        15051977
# 4637           3   several     2002-05-24           38000000        39177215
#
#       worldwide_gross  total_profit  was_it_profitable_domestically  \
# 0           494870992     329870992                            True
# 1           621156389     451156389                            True
# 2           835524642     675524642                            True
# 3           223050874     128050874                           False
# 4          2776345279    2351345279                            True
# ...               ...           ...                             ...
# 4611         69157016       -842984                           False
# 4613           295492      -6904508                           False
# 4619            17396     -20982604                           False
# 4622         34356760       9356760                           False
# 4637         50970660      12970660                            True
#
#       month_of_release
# 0                    3
# 1                    5
# 2                    7
# 3                    2
# 4                   12
# ...                ...
# 4611                 6
# 4613                 9
# 4619                10
# 4622                11
# 4637                 5
#
# [1834 rows x 13 columns]

# %%
#Visualize Vote_count vs. Average vote

fig, ax = plt.subplots()
fig.set_size_inches(8,12)
ax=sns.scatterplot(x='vote_average', y='vote_count', marker='o', ci=68, data=df_final)
ax.set(xlabel='Average Movie Rating (1-10)', ylabel='Vote Count')
sns.set(style='whitegrid')
plt.show()

# %% [markdown]
# #To avoid movies with fewer vote counts, affecting our analysis, we will only consider movies with vote counts higher than 500. We will also round off the vote_average to the nearest whole number.

# %%
gross_vote = df_final[['worldwide_gross', 'vote_count', 'vote_average']]
votes_above_500 = gross_vote.loc[gross_vote['vote_count'] >= 500]
votes_above_500 = votes_above_2000.round(1)
votes_above_500
# Out:
#       worldwide_gross  vote_count  vote_average
# 0           494870992        7610           8.0
# 1           621156389       12368           7.0
# 2           835524642       22186           8.0
# 3           223050874        4229           6.0
# 4          2776345279       18676           7.0
# ...               ...         ...           ...
# 4577         71118378        1312           6.0
# 4582        133401882        1073           5.0
# 4583         44378040         884           6.0
# 4586         56096200         799           5.0
# 4596        122747755         721           7.0
#
# [979 rows x 3 columns]

# %%
df_avgVote_Revenue = votes_above_500.groupby('vote_average', as_index=False).mean()
df_avgVote_Revenue
# Out:
#    vote_average  worldwide_gross   vote_count
# 0           4.0     7.099619e+07  1232.250000
# 1           5.0     9.547505e+07  1494.144928
# 2           6.0     1.733979e+08  2184.889135
# 3           7.0     2.163830e+08  3454.039216
# 4           8.0     3.559511e+08  6422.989362

# %%
#Visualize Average votes and Gross Revenue

fig, ax = plt.subplots()
fig.set_size_inches(20,10)

ax = sns.barplot(x='vote_average', y='worldwide_gross', data=df_avgVote_Revenue)
sns.set_palette('Blues')
plt.yticks(ax.get_yticks(), ax.get_yticks()/1000000)
plt.xlabel('Average movie Rating (1-10)')
plt.ylabel('Gross Movie Revenue')
plt.show()
